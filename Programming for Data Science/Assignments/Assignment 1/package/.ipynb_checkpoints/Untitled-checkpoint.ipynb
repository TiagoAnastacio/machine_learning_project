# %%
# %load main.py
from yahtzee import *

def main():
    """Main game loop for Yahtzee."""
    name = input('Enter your name please:')
    print(f"Welcome to Yahtzee, {name}!")
    
    
    # Initialize scorecard
    card = create_empty_scorecard() 

    # Play 13 rounds 
    for i in range(2):
        play_round(card)
        if i != 1:
            print(f'---------------Round: {i+1}-------------- ')
        else:
            print(f'---------------Final Scorecard-------------- ')
        
    
    # Display scorecard after each round
    upper = sum((card[k] or 0) for k in ('1','2','3','4','5','6'))
    bonus = 35 if upper >= 63 else 0
    total = bonus + sum((v or 0) for v in card.values())


    # Calculate final score
    # If upper section total >= 63, bonus = 35
    # --- [Your code here] ---
    
    print(f"\nGame over! Final score: {total}\nWell Done, {name}")

if __name__ == "__main__":
    main()
# Out:
# Enter your name please: Laura
# Welcome to Yahtzee, Laura!
# Your current hand is:[1, 5, 4, 3, 3]
# Your current scorecard is:
# {'1': 1, '2': 0, '3': 6, '4': 4, '5': 5, '6': 0, 'three_of_a_kind': None, 'four_of_a_kind': None, 'full_house': None, 'four_straight': None, 'five_straight': None, 'yahtzee': None, 'chance': 16}
# Which dice to keep? 143
# Your current hand is:[1, 4, 3, 1, 5]
# Your current scorecard is:
# {'1': 2, '2': 0, '3': 3, '4': 4, '5': 5, '6': 0, 'three_of_a_kind': None, 'four_of_a_kind': None, 'full_house': None, 'four_straight': None, 'five_straight': None, 'yahtzee': None, 'chance': 14}
# Which dice to keep? 1143
# Your final hand is:[1, 1, 4, 3, 2]
# Your final scorecard is:
# {'1': 2, '2': 2, '3': 3, '4': 4, '5': 0, '6': 0, 'three_of_a_kind': None, 'four_of_a_kind': None, 'full_house': None, 'four_straight': 30, 'five_straight': None, 'yahtzee': None, 'chance': 11}
# Which one to fill? four straight
# Input not valid check for spelling mistakes Try again.
# Which one to fill? four_straight
# 1: None
# 2: None
# 3: None
# 4: None
# 5: None
# 6: None
# three_of_a_kind: None
# four_of_a_kind: None
# full_house: None
# four_straight: 30
# five_straight: None
# yahtzee: None
# chance: None
# Upper Section Score: 0
# Bonus: 0
# Total Score: 30
# ---------------Round: 1--------------
# Your current hand is:[5, 4, 5, 3, 4]
# Your current scorecard is:
# {'1': 0, '2': 0, '3': 3, '4': 8, '5': 10, '6': 0, 'three_of_a_kind': None, 'four_of_a_kind': None, 'full_house': None, 'four_straight': None, 'five_straight': None, 'yahtzee': None, 'chance': 21}
# Which dice to keep? 4455
# Your current hand is:[4, 4, 5, 5, 1]
# Your current scorecard is:
# {'1': 1, '2': 0, '3': 0, '4': 8, '5': 10, '6': 0, 'three_of_a_kind': None, 'four_of_a_kind': None, 'full_house': None, 'four_straight': None, 'five_straight': None, 'yahtzee': None, 'chance': 19}
# Which dice to keep? 4455
# Your final hand is:[4, 4, 5, 5, 6]
# Your final scorecard is:
# {'1': 0, '2': 0, '3': 0, '4': 8, '5': 10, '6': 6, 'three_of_a_kind': None, 'four_of_a_kind': None, 'full_house': None, 'four_straight': None, 'five_straight': None, 'yahtzee': None, 'chance': 24}
# Which one to fill? chance
# 1: None
# 2: None
# 3: None
# 4: None
# 5: None
# 6: None
# three_of_a_kind: None
# four_of_a_kind: None
# full_house: None
# four_straight: 30
# five_straight: None
# yahtzee: None
# chance: 24
# Upper Section Score: 0
# Bonus: 0
# Total Score: 54
# ---------------Final Scorecard--------------
#
# Game over! Final score: 54
# WELL DONE Laura
