# %%
print("hello world")
# Out:
# hello world

# %%
my_string = "Tiago"

# %%
print(f"Hello my name is {my_string}")
# Out:
# Hello my name is Tiago

# %%
print("Hello my name is " + my_string)
# Out:
# Hello my name is Tiago

# %%
print("Hello I am",25+2,"years old")
#My age
# Out:
# Hello I am 27 years old

# %%
my_list = [1,2,True,4,5,None,"Apple"]

# %%
my_list[0]
# Out:
# 1

# %%
my_tuple = (1,2)

# %%
my_tuple [0] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 my_tuple [0] = 3
#
# TypeError: 'tuple' object does not support item assignment

# %%
1 > 2
# Out:
# False

# %%
4 % 2 == 0
# Out:
# True

# %%
my_dict = {"jan":1,"apr":4,"jun":6}

# %%
my_dict.keys()
# Out:
# dict_keys(['jan', 'apr', 'jun'])

# %%
my_dict.values()
# Out:
# dict_values([1, 4, 6])

# %%
my_dict["jan"]
# Out:
# 1
